# %% [markdown]
# # World Happiness Report 2021

# %% [markdown]
# Context
#
# The World Happiness Report is a landmark survey of the state of global happiness . The report continues to gain global recognition as governments, organizations and civil society increasingly use happiness indicators to inform their policy-making decisions. Leading experts across fields – economics, psychology, survey analysis, national statistics, health, public policy and more – describe how measurements of well-being can be used effectively to assess the progress of nations. The reports review the state of happiness in the world today and show how the new science of happiness explains personal and national variations in happiness.
#
# Content
#
# The happiness scores and rankings use data from the Gallup World Poll . The columns following the happiness score estimate the extent to which each of six factors – economic production, social support, life expectancy, freedom, absence of corruption, and generosity – contribute to making life evaluations higher in each country than they are in Dystopia, a hypothetical country that has values equal to the world’s lowest national averages for each of the six factors. They have no impact on the total score reported for each country, but they do explain why some countries rank higher than others.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set_style('darkgrid')
plt.rcParams['font.size'] = 15
plt.rcParams['figure.figsize'] = (10, 7)
plt.rcParams['figure.facecolor'] = '#EBF4FA'

# %%
df = pd.read_csv('world-happiness-report-2021.csv')
df
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
data_columns = ['Country name', 'Regional indicator', 'Ladder score', 'Logged GDP per capita', 'Social support', 'Healthy life expectancy', 'Freedom to make life choices', 'Generosity', 'Perceptions of corruption']
df = df[data_columns].copy()
df
# Out:
#     Country name  Regional indicator  Ladder score  Logged GDP per capita  \
# 0        Finland      Western Europe         7.842                 10.775
# 1        Denmark      Western Europe         7.620                 10.933
# 2    Switzerland      Western Europe         7.571                 11.117
# 3        Iceland      Western Europe         7.554                 10.878
# 4    Netherlands      Western Europe         7.464                 10.932
# ..           ...                 ...           ...                    ...
# 144      Lesotho  Sub-Saharan Africa         3.512                  7.926
# 145     Botswana  Sub-Saharan Africa         3.467                  9.782
# 146       Rwanda  Sub-Saharan Africa         3.415                  7.676
# 147     Zimbabwe  Sub-Saharan Africa         3.145                  7.943
# 148  Afghanistan          South Asia         2.523                  7.695
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# ...

# %%
df1 = df.rename({'Country name' : 'country name', 'Regional indicator' : 'regional indicator', 'Ladder score' : 'happiness score', 'Logged GDP per capita' : 'logged GDP per capita', 'Social support' : 'social support', 'Healthy life expectancy' : 'health life expectancy', 'Freedom to make life choices' : 'freedom to make life choices', 'Generosity' : 'generosity', 'Perceptions of corruption' : 'perceptions of curruption'}, axis = 1)
df1.head()
# Out:
#   country name regional indicator  happiness score  logged GDP per capita  \
# 0      Finland     Western Europe            7.842                 10.775
# 1      Denmark     Western Europe            7.620                 10.933
# 2  Switzerland     Western Europe            7.571                 11.117
# 3      Iceland     Western Europe            7.554                 10.878
# 4  Netherlands     Western Europe            7.464                 10.932
#
#    social support  health life expectancy  freedom to make life choices  \
# 0           0.954                    72.0                         0.949
# 1           0.954                    72.7                         0.946
# 2           0.942                    74.4                         0.919
# 3           0.983                    73.0                         0.955
# 4           0.942                    72.4                         0.913
#
#    generosity  perceptions of curruption
# 0      -0.098                      0.186
# ...

# %%
df1.isnull().sum()
# Out:
# country name                    0
# regional indicator              0
# happiness score                 0
# logged GDP per capita           0
# social support                  0
# health life expectancy          0
# freedom to make life choices    0
# generosity                      0
# perceptions of curruption       0
# dtype: int64

# %%
df1.isna().sum()
# Out:
# country name                    0
# regional indicator              0
# happiness score                 0
# logged GDP per capita           0
# social support                  0
# health life expectancy          0
# freedom to make life choices    0
# generosity                      0
# perceptions of curruption       0
# dtype: int64

# %%
df1.dtypes
# Out:
# country name                     object
# regional indicator               object
# happiness score                 float64
# logged GDP per capita           float64
# social support                  float64
# health life expectancy          float64
# freedom to make life choices    float64
# generosity                      float64
# perceptions of curruption       float64
# dtype: object

# %%
plt.rcParams['figure.figsize'] = (15,7)
plt.title('Plot between Happiness Score and GDP')
sns.scatterplot(data=df1, x="happiness score", y="logged GDP per capita", hue = "regional indicator", s = 200);

plt.legend(loc = 'upper left', fontsize = '10')
plt.xlabel('Happiness Score')
plt.ylabel('GDP per Capita')
# Out:
# Text(0, 0.5, 'GDP per Capita')

# %%
gdp_region = df1.groupby('regional indicator')['logged GDP per capita'].sum()
gdp_region
# Out:
# regional indicator
# Central and Eastern Europe            171.854
# Commonwealth of Independent States    112.822
# East Asia                              62.206
# Latin America and Caribbean           187.400
# Middle East and North Africa          164.324
# North America and ANZ                  43.238
# South Asia                             60.778
# Southeast Asia                         84.793
# Sub-Saharan Africa                    290.707
# Western Europe                        227.277
# Name: logged GDP per capita, dtype: float64

# %%
gdp_region.plot.pie(autopct = '%1.1f%%')
plt.title('GDP by Region')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
total_country = df1.groupby('regional indicator')[['country name']].count()
total_country
# Out:
#                                     country name
# regional indicator
# Central and Eastern Europe                    17
# Commonwealth of Independent States            12
# East Asia                                      6
# Latin America and Caribbean                   20
# Middle East and North Africa                  17
# North America and ANZ                          4
# South Asia                                     7
# Southeast Asia                                 9
# Sub-Saharan Africa                            36
# Western Europe                                21

# %%
cor = df.corr(method = "pearson")
f, ax = plt.subplots(figsize = (10, 5))
sns.heatmap(cor, mask = np.zeros_like(cor, dtype = np.bool), cmap = 'Reds', square = True, ax = ax)
# Out:
# C:\Users\pinil\AppData\Local\Temp\ipykernel_9956\843517693.py:3: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   sns.heatmap(cor, mask = np.zeros_like(cor, dtype = np.bool), cmap = 'Reds', square = True, ax = ax)
# <AxesSubplot:>

# %%
corruption = df1.groupby('regional indicator')[['perceptions of curruption']].mean()
corruption
# Out:
#                                     perceptions of curruption
# regional indicator
# Central and Eastern Europe                           0.850529
# Commonwealth of Independent States                   0.725083
# East Asia                                            0.683333
# Latin America and Caribbean                          0.792600
# Middle East and North Africa                         0.762235
# North America and ANZ                                0.449250
# South Asia                                           0.797429
# Southeast Asia                                       0.709111
# Sub-Saharan Africa                                   0.765944
# Western Europe                                       0.523095

# %%
plt.rcParams['figure.figsize'] = (12, 8)
plt.title('Perception of Corruption in Various Regions')
plt.xlabel('Regions', fontsize = 15)
plt.ylabel('Corruption Index', fontsize = 15)
plt.xticks(rotation = 30, ha = 'right')
plt.bar(corruption.index, corruption.perceptions of corruption)
# Out:
#   File "C:\Users\pinil\AppData\Local\Temp\ipykernel_9956\3244400720.py", line 6
#     plt.bar(corruption.index, corruption.perceptions of corruption)
#                                                      ^
# SyntaxError: invalid syntax
